# %%
array=["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]
print(array[2])
# Out:
# 水曜日は晴れです

# %%
dictionary={"mon":"晴れ","tue":"雨","wed":"晴れ","thu":"晴れ","fri":"曇り","sat":"曇りのち雨","sun":"雷雨"}
print(dictionary["wed"])
# Out:
# 晴れ

# %%
import random

num=random.randint(0,4)
#変数numの値を出力
print(num)
#変数numの値が4であれば、大当たりですという文字列を出力する
if num == 4:
    print("大当たりです")
# Out:
# 2

# %%
import random
num=random.randint(0,4)
print(num)
if num==4:
  print("大当たりです")

else:
  print("ハズレです")
# Out:
# 1
# ハズレです

# %%
import random
#変数numに0~4までのランダムな整数に代入する
num=random.randint(0,4)
print(num)
if 1<num and num<3:
 print("変数numは１より大きく３より小さいです")

else:
 print("and条件が成り立ちませんでした")

if num ==1 or num==3:
  print("変数numは１または３です")

else:
 print("or条件が成り立ちませんでした")
# Out:
# 0
# and条件が成り立ちませんでした
# or条件が成り立ちませんでした

# %%
var=15

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")

elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
    print("Buzz")
else:
    print(var)
# Out:
# FizzBuzz
