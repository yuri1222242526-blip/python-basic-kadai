# %%
age = 18
if age < 20:
    print("ジュースで乾杯！")
else:
    print("お酒で乾杯！")
# Out:
# ジュースで乾杯！

# %%
print(45+5)
print(45-5)
print(45*5)
print(45/5)
print(45%5)
# Out:
# 50
# 40
# 225
# 9.0
# 0

# %%
print("降水確率" + str(50)+ "%")
# Out:
# 降水確率50%

# %%
user_name = "侍太郎"
print(user_name)
# Out:
# 侍太郎

# %%
top_line=10
under_line=20
height=5
area=(top_line + under_line)*height/2
print(str(area) + "㎡")
# Out:
# 75.0㎡
