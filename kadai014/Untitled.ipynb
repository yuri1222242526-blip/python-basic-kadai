# %%
price1 = 100
price2 = 200
tax = 1.1

tax_total = (price1 + price2) * tax

def total():
    subtotal = price1 + price2  # ローカル変数
    return subtotal * tax

print(total())
print(tax_total)
# Out:
# 330.0
# 330.0
